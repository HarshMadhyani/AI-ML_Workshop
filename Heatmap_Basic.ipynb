# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
arr_2d = np.linspace(1,5,12).reshape(4,3)
arr_2d
# Out:
# array([[1.        , 1.36363636, 1.72727273],
#        [2.09090909, 2.45454545, 2.81818182],
#        [3.18181818, 3.54545455, 3.90909091],
#        [4.27272727, 4.63636364, 5.        ]])

# %%
sns.heatmap(arr_2d)
# Out:
# <Axes: >

# %%
df = pd.DataFrame({
    "Maths":[95,64,78,21,75],
    "English":[55,65,78,43,89],
    "Science":[95,64,78,21,75]
})
df
# Out:
#    Maths  English  Science
# 0     95       55       95
# 1     64       65       64
# 2     78       78       78
# 3     21       43       21
# 4     75       89       75

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
sns.heatmap(df,annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df,annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.heatmap(df,annot=True,cmap="Greens")
# Out:
# <Axes: >

# %%
sns.heatmap(df,annot=True,cmap="Greens",linewidths=1,linecolor="black")
# Out:
# <Axes: >

# %%
global_warning_example = sns.load_dataset('flights')

# %%
globalwarning = pd.read_csv("/content/drive/MyDrive/Datasets/Copy of Who_is_responsible_for_global_warming.csv")
globalwarning
# Out:
#           Country Name Country Code                          Indicator Name  \
# 0        United States          USA  CO2 emissions (metric tons per capita)
# 1       United Kingdom          GBR  CO2 emissions (metric tons per capita)
# 2                India          IND  CO2 emissions (metric tons per capita)
# 3                China          CHN  CO2 emissions (metric tons per capita)
# 4   Russian Federation          RUS  CO2 emissions (metric tons per capita)
# 5            Australia          AUS  CO2 emissions (metric tons per capita)
# 6               France          FRA  CO2 emissions (metric tons per capita)
# 7              Germany          DEU  CO2 emissions (metric tons per capita)
# 8               Canada          CAN  CO2 emissions (metric tons per capita)
# 9               Brazil          BRA  CO2 emissions (metric tons per capita)
# 10           Argentina          ARG  CO2 emissions (metric tons per capita)
# ...

# %%
heatmap_data = globalwarning.drop(['Country Code','Indicator Name','Indicator Code'],axis =1 ).set_index('Country Name')
sns.heatmap(heatmap_data, cmap='viridis', linewidths=0.5, linecolor='white', annot=False, vmin=0, vmax=20)
# Out:
# <Axes: ylabel='Country Name'>

# %%
gwds = globalwarning.drop(['Country Code', 'Indicator Name','Indicator Code'], axis=1).set_index('Country Name')
gwds
# Out:
#                          2000       2001       2002       2003       2004  \
# Country Name
# United States       20.178751  19.636505  19.613404  19.564105  19.658371
# United Kingdom       9.199549   9.233175   8.904123   9.053278   8.989140
# India                0.979870   0.971698   0.967381   0.992392   1.025028
# China                2.696862   2.742121   3.007083   3.524074   4.037991
# Russian Federation  10.627121  10.669603  10.715901  11.090647  11.120627
# Australia           17.200610  16.733367  17.370452  16.901959  17.026515
# France               5.946665   6.153061   6.068664   6.115998   6.120079
# Germany             10.095640  10.366287  10.058673   9.969355   9.898682
# Canada              17.367115  16.985030  16.559378  17.461199  17.258911
# Brazil               1.871118   1.898354   1.844380   1.762482   1.828672
# Argentina            3.835574   3.568600   3.291548   3.525584   4.069058
# ...

# %%
sns.heatmap(gwds,cmap='coolwarm')
# Out:
# <Axes: ylabel='Country Name'>

# %%
sns.heatmap(gwds,cmap='coolwarm',linewidths=1,linecolor='black',alpha=0.5)
# Out:
# <Axes: ylabel='Country Name'>

# %%
sns.heatmap(gwds,cmap='coolwarm')
# Out:
# <Axes: ylabel='Country Name'>
